# %% [markdown]
# - 데이터 자료 : [Kaggle Titanic - Machine Learning from Disater](https://www.kaggle.com/c/titanic/data?select=train.csv) train.csv파일
#
# |컬럼|설명|
# |-|-|
# |PassengerId|승객 ID|
# |Survived|생존 여부 (0/1)|
# |Pclass|객실 등급|
# |Name|이름|
# |Sex|성별|
# |Age|나이|
# |SibSp|형제/배우자 수|
# |Parch|부모/자녀 수|
# |Ticket|티켓 번호|
# |Fare|운임요금|
# |Cabin|객실 번호|
# |Embarked|승선 항구|

# %% [markdown]
# ## 공통 라이브러리 import

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 문제 1
# Titanic 데이터를 불러와 df 변수에 저장하시오.

# %% [markdown]
# ## 문제 2
#
# 데이터의 행과 열 개수를 확인하시오.

# %% [markdown]
# ## 문제 3
#
# 각 컬럼의 결측치 개수를 확인하시오.

# %% [markdown]
# ## 문제 4
#
# `Age` 컬럼의 결측치를 평균값으로 대체하시오.

# %% [markdown]
# ## 문제 5
# `Embarked` 컬럼의 결측치를 최빈값으로 대체하시오.

# %% [markdown]
# ## 문제 6
# `Survived` 컬럼의 분포를 막대그래프로 시각화하시오.
# - seaborn 사용

# %% [markdown]
# ## 문제 7
# `Age` 컬럼의 분포를 히스토그램으로 시각화하시오.

# %% [markdown]
# ## 문제 8
# 다음 범주형 변수를 One-Hot Encoding 하시오.
# - Sex
# - Embarked
#
# 조건:
# - 첫 번째 카테고리는 제거할 것

# %% [markdown]
# ## 문제 9
# `Pclass, Age, Fare, Sex_male, Embarked_Q, Embarked_S`  컬럼만 사용하여 Feature(X)를 생성하시오.
# Target(y)은 Survived를 사용하시오.

# %% [markdown]
# ## 문제 10
# 학습 데이터와 테스트 데이터를 분리하시오.
#
# 조건: `test_size=0.2`, `random_state=42`

# %% [markdown]
# ## 문제 11
# `StandardScaler`를 사용하여 학습 데이터와 테스트 데이터를 스케일링하시오.
#
# 주의:
# - 데이터 누수(Data Leakage)가 발생하지 않도록 처리할 것

# %% [markdown]
# ## 문제 12
# 다음 조건으로 Random Forest 모델을 생성하시오.
#
# 조건: `n_estimators = 100`, `random_state = 42`

# %% [markdown]
# ## 문제 13
#
# 모델을 학습시키고 테스트 데이터에 대한 예측값을 생성하시오.

# %% [markdown]
# ## 문제 14
#
# 아래 평가 지표를 모두 출력하시오.
#
# - Accuracy
# - Confusion Matrix
# - Classification Report

# %% [markdown]
# # 추가 실전 문제
# ## 문제 15
#
# 중복 데이터 개수를 확인하시오.

# %% [markdown]
# ## 문제 16
#
# 중복 데이터를 제거한 새로운 데이터프레임을 생성하시오.

# %% [markdown]
# ## 문제 17
#
# 숫자형 컬럼들에 대한 상관관계 행렬을 구하시오.

# %% [markdown]
# ## 문제 18
#
# 상관관계 행렬을 Heatmap으로 시각화하시오.
#
# 조건:
# - 상관계수 값을 표시할 것

# %% [markdown]
# ## 문제 19
#
# Random Forest 모델의 Feature Importance를 출력하고 중요도가 높은 순으로 정렬하시오.

# %% [markdown]
# ## 문제 20
#
# Age와 Fare 컬럼에 대해 Boxplot을 그려 이상치를 확인하시오.

# %% [markdown]
# # 실전 난이도 업 문제
# ## 문제 21
#
# Age 컬럼을 아래 기준으로 구간화하여 Age_Group 컬럼을 생성하시오.
# - 0~19 : Yong
# - 20~59 : Adult
# - 60 이상 :Senior

# %% [markdown]
# ## 문제 22
#
# 생성한 Age_Group별 생존율을 계산하시오.

# %% [markdown]
# ## 문제 23
#
# `성별(Sex)`에 따른 생존율을 계산하시오.

# %% [markdown]
# ## 문제 24
#
# 객실등급(Pclass)별 평균 운임(Fare)을 계산하시오.

# %% [markdown]
# ## 문제 25
#
# 생존 여부(Survived)를 예측하는 Logistic Regression 모델을 생성하고 성능을 평가하시오.
